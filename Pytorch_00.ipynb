# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosedva/Pytorch/blob/main/Pytorch_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hola Mundo!"
# Out:
# 'Hola Mundo!'

# %%
print("Hola Mundo!")
# Out:
# Hola Mundo!
